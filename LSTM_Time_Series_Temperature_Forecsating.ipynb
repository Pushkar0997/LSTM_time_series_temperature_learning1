# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np

# %%
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)
csv_path, _ = os.path.splitext(zip_path)

# Get the directory where the zip file was extracted
datasets_dir = os.path.dirname(csv_path)

# Construct the expected path to the CSV file within the extracted directory
csv_file_path = os.path.join(datasets_dir, 'jena_climate_2009_2016.csv')

# Check if the file was extracted to a subdirectory with the same name (without .zip)
extracted_dir = os.path.join(datasets_dir, os.path.splitext(os.path.basename(zip_path))[0])
if os.path.exists(extracted_dir):
    # If the subdirectory exists, update the CSV file path
    csv_file_path = os.path.join(extracted_dir, 'jena_climate_2009_2016.csv')

# Check if the file was found
if not os.path.exists(csv_file_path):
    raise FileNotFoundError(f"Could not find 'jena_climate_2009_2016.csv' in {datasets_dir}")

# %%
# Now use the corrected file path to read the CSV
df = pd.read_csv(csv_file_path)
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df = df[5::6]
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')
df[:26]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71     -9.67    263.66
# 2009-01-01 07:00:00  01.01.2009 07:00:00    998.33     -9.17    264.12
# 2009-01-01 08:00:00  01.01.2009 08:00:00    999.17     -8.10    265.12
# 2009-01-01 09:00:00  01.01.2009 09:00:00    999.69     -7.66    265.52
# 2009-01-01 10:00:00  01.01.2009 10:00:00   1000.27     -7.04    266.10
# 2009-01-01 11:00:00  01.01.2009 11:00:00   1000.87     -7.41    265.68
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30     -6.87    266.27
# ...

# %%
temp = df['T (degC)']
temp.plot()
# Out:
# <Axes: xlabel='Date Time'>

# %%
# [[[1], [2], [3], [4], [5]]] [6]
# [[[2], [3], [4], [5], [6]]] [7]
# [[[3], [4], [5], [6], [7]]] [8]

def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
X1.shape, y1.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
X_train1, y_train1 = X1[:60000], y1[:60000]
X_val1, y_val1 = X1[60000:65000], y1[60000:65000]
X_test1, y_test1 = X1[65000:], y1[65000:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (5086, 5, 1), (5086,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,425 (68.07 KB)
#  Trainable params: 17,425 (68.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp1 = ModelCheckpoint('model1/model.keras', save_best_only=True) # Add a file extension to the filepath argument (e.g., .keras or .h5)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp1])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 78.6960 - root_mean_squared_error: 8.6608 - val_loss: 1.2916 - val_root_mean_squared_error: 1.1365
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.3564 - root_mean_squared_error: 1.8237 - val_loss: 0.6100 - val_root_mean_squared_error: 0.7810
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 1.0589 - root_mean_squared_error: 1.0286 - val_loss: 0.5334 - val_root_mean_squared_error: 0.7303
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.7505 - root_mean_squared_error: 0.8663 - val_loss: 0.5113 - val_root_mean_squared_error: 0.7150
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.6876 - root_mean_squared_error: 0.8292 - val_loss: 0.5237 - val_root_mean_squared_error: 0.7237
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.6560 - root_mean_squared_error: 0.8098 - val_loss: 0.4991 - val_root_mean_squared_error: 0.7065
# ...

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1/model.keras')

# %%
train_predictions = model1.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
#        Train Predictions  Actuals
# 0             -10.005507    -9.67
# 1              -9.776068    -9.17
# 2              -8.867435    -8.10
# 3              -7.338335    -7.66
# 4              -7.265337    -7.04
# ...                  ...      ...
# 59995           6.099857     6.07
# 59996           7.265984     9.88
# 59997          12.007194    13.53
# 59998          15.673461    15.43
# 59999          16.381517    15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Train Predictions'][50:100])
plt.plot(train_results['Actuals'][50:100])

# %%
val_predictions = model1.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#       Val Predictions  Actuals
# 0           15.559409    14.02
# 1           13.341589    13.67
# 2           13.092341    12.27
# 3           11.491572    11.19
# 4           10.413920    10.85
# ...               ...      ...
# 4995        17.546606    18.27
# 4996        17.542648    17.85
# 4997        17.285547    16.65
# 4998        15.951478    15.85
# 4999        15.135925    15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][:100])
plt.plot(val_results['Actuals'][:100])

# %%
test_predictions = model1.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#       Test Predictions  Actuals
# 0            14.437852    13.99
# 1            13.260679    13.46
# 2            12.907341    12.93
# 3            12.502490    12.43
# 4            12.050918    12.17
# ...                ...      ...
# 5081         -1.066800    -0.98
# 5082         -1.405801    -1.40
# 5083         -1.651604    -2.75
# 5084         -3.348219    -2.89
# 5085         -3.163700    -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])

# %%
#Split

# %%
from sklearn.metrics import mean_squared_error as mse

def plot_predictions1(model, X, y, start=0, end=100):
  predictions = model.predict(X).flatten()
  df = pd.DataFrame(data={'Predictions': predictions, 'Actuals':y})
  plt.plot(df['Predictions'][start:end])
  plt.plot(df['Actuals'][start:end])
  return df, mse(predictions, y)

# %%
plot_predictions1(model1, X_test1, y_test1)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# (      Predictions  Actuals
#  0       14.437852    13.99
#  1       13.260679    13.46
#  2       12.907341    12.93
#  3       12.502490    12.43
#  4       12.050918    12.17
#  ...           ...      ...
#  5081    -1.066800    -0.98
#  5082    -1.405801    -1.40
#  5083    -1.651604    -2.75
#  5084    -3.348219    -2.89
#  5085    -3.163700    -3.93
#
#  [5086 rows x 2 columns],
#  0.6089735479841443)

# %%
model2 = Sequential()
model2.add(InputLayer((5, 1)))
model2.add(Conv1D(64, kernel_size=2, activation='relu'))
model2.add(Flatten())
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 4, 64)          │           192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │         2,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,257 (8.82 KB)
#  Trainable params: 2,257 (8.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp2 = ModelCheckpoint('model2/model.keras', save_best_only=True) # Add a file extension to the filepath argument (e.g., .keras or .h5)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp2])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 19.0940 - root_mean_squared_error: 4.0690 - val_loss: 0.8854 - val_root_mean_squared_error: 0.9409
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 1.0952 - root_mean_squared_error: 1.0458 - val_loss: 0.6404 - val_root_mean_squared_error: 0.8003
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7960 - root_mean_squared_error: 0.8921 - val_loss: 0.5534 - val_root_mean_squared_error: 0.7439
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.7076 - root_mean_squared_error: 0.8411 - val_loss: 0.5126 - val_root_mean_squared_error: 0.7159
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.6805 - root_mean_squared_error: 0.8247 - val_loss: 0.5054 - val_root_mean_squared_error: 0.7109
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.6582 - root_mean_squared_error: 0.8112 - val_loss: 0.4927 - val_root_mean_squared_error: 0.7019
# Epoch 7/10
# ...

# %%
plot_predictions1(model2, X_test1, y_test1)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# (      Predictions  Actuals
#  0       14.328037    13.99
#  1       13.211255    13.46
#  2       12.876646    12.93
#  3       12.435094    12.43
#  4       12.004996    12.17
#  ...           ...      ...
#  5081    -0.473992    -0.98
#  5082    -1.307264    -1.40
#  5083    -1.491696    -2.75
#  5084    -2.596967    -2.89
#  5085    -3.068306    -3.93
#
#  [5086 rows x 2 columns],
#  0.6458377152590934)

# %%
model3 = Sequential()
model3.add(InputLayer((5, 1)))
model3.add(GRU(64))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 64)             │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,393 (52.32 KB)
#  Trainable params: 13,393 (52.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp3 = ModelCheckpoint('model3/model.keras', save_best_only=True) # Added 'model.keras' to filepath argument
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model3.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp3])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 145.5397 - root_mean_squared_error: 12.0517 - val_loss: 24.9674 - val_root_mean_squared_error: 4.9967
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 50.8135 - root_mean_squared_error: 7.0995 - val_loss: 3.1702 - val_root_mean_squared_error: 1.7805
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 10.7526 - root_mean_squared_error: 3.2618 - val_loss: 0.7689 - val_root_mean_squared_error: 0.8768
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 2.6351 - root_mean_squared_error: 1.6190 - val_loss: 0.5572 - val_root_mean_squared_error: 0.7464
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 1.2182 - root_mean_squared_error: 1.1012 - val_loss: 0.5126 - val_root_mean_squared_error: 0.7160
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.7847 - root_mean_squared_error: 0.8857 - val_loss: 0.5046 - val_root_mean_squared_error: 0.7104
# ...

# %%
temp
# Out:
# Date Time
# 2009-01-01 01:00:00   -8.05
# 2009-01-01 02:00:00   -8.88
# 2009-01-01 03:00:00   -8.81
# 2009-01-01 04:00:00   -9.05
# 2009-01-01 05:00:00   -9.63
#                        ...
# 2016-12-31 19:10:00   -0.98
# 2016-12-31 20:10:00   -1.40
# 2016-12-31 21:10:00   -2.75
# 2016-12-31 22:10:00   -2.89
# 2016-12-31 23:10:00   -3.93
# Name: T (degC), Length: 70091, dtype: float64

# %%
temp_df = pd.DataFrame({'Temperature':temp})
temp_df['Seconds'] = temp_df.index.map(pd.Timestamp.timestamp)
temp_df
# Out:
#                      Temperature       Seconds
# Date Time
# 2009-01-01 01:00:00        -8.05  1.230772e+09
# 2009-01-01 02:00:00        -8.88  1.230775e+09
# 2009-01-01 03:00:00        -8.81  1.230779e+09
# 2009-01-01 04:00:00        -9.05  1.230782e+09
# 2009-01-01 05:00:00        -9.63  1.230786e+09
# ...                          ...           ...
# 2016-12-31 19:10:00        -0.98  1.483211e+09
# 2016-12-31 20:10:00        -1.40  1.483215e+09
# 2016-12-31 21:10:00        -2.75  1.483219e+09
# 2016-12-31 22:10:00        -2.89  1.483222e+09
# 2016-12-31 23:10:00        -3.93  1.483226e+09
#
# [70091 rows x 2 columns]

# %%
day = 24*60*60
year = (365.2425)*day

temp_df['Day sin'] = np.sin(temp_df['Seconds'] * (2 * np.pi / day))
temp_df['Day cos'] = np.cos(temp_df['Seconds'] * (2 * np.pi / day))
temp_df['Year sin'] = np.sin(temp_df['Seconds'] * (2 * np.pi / year))
temp_df['Year cos'] = np.cos(temp_df['Seconds'] * (2 * np.pi / year))
temp_df
# Out:
#                      Temperature       Seconds   Day sin   Day cos  Year sin  \
# Date Time
# 2009-01-01 01:00:00        -8.05  1.230772e+09  0.258819  0.965926  0.010049
# 2009-01-01 02:00:00        -8.88  1.230775e+09  0.500000  0.866025  0.010766
# 2009-01-01 03:00:00        -8.81  1.230779e+09  0.707107  0.707107  0.011483
# 2009-01-01 04:00:00        -9.05  1.230782e+09  0.866025  0.500000  0.012199
# 2009-01-01 05:00:00        -9.63  1.230786e+09  0.965926  0.258819  0.012916
# ...                          ...           ...       ...       ...       ...
# 2016-12-31 19:10:00        -0.98  1.483211e+09 -0.953717  0.300706  0.006900
# 2016-12-31 20:10:00        -1.40  1.483215e+09 -0.843391  0.537300  0.007617
# 2016-12-31 21:10:00        -2.75  1.483219e+09 -0.675590  0.737277  0.008334
# 2016-12-31 22:10:00        -2.89  1.483222e+09 -0.461749  0.887011  0.009050
# 2016-12-31 23:10:00        -3.93  1.483226e+09 -0.216440  0.976296  0.009767
#
#                      Year cos
# ...

# %%
temp_df = temp_df.drop('Seconds', axis=1)
temp_df
# Out:
#                      Temperature   Day sin   Day cos  Year sin  Year cos
# Date Time
# 2009-01-01 01:00:00        -8.05  0.258819  0.965926  0.010049  0.999950
# 2009-01-01 02:00:00        -8.88  0.500000  0.866025  0.010766  0.999942
# 2009-01-01 03:00:00        -8.81  0.707107  0.707107  0.011483  0.999934
# 2009-01-01 04:00:00        -9.05  0.866025  0.500000  0.012199  0.999926
# 2009-01-01 05:00:00        -9.63  0.965926  0.258819  0.012916  0.999917
# ...                          ...       ...       ...       ...       ...
# 2016-12-31 19:10:00        -0.98 -0.953717  0.300706  0.006900  0.999976
# 2016-12-31 20:10:00        -1.40 -0.843391  0.537300  0.007617  0.999971
# 2016-12-31 21:10:00        -2.75 -0.675590  0.737277  0.008334  0.999965
# 2016-12-31 22:10:00        -2.89 -0.461749  0.887011  0.009050  0.999959
# 2016-12-31 23:10:00        -3.93 -0.216440  0.976296  0.009767  0.999952
#
# [70091 rows x 5 columns]

# %%
def df_to_X_y2(df, window_size=6):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [r for r in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size][0]
    y.append(label)
  return np.array(X), np.array(y)

# %%
X2, y2 = df_to_X_y2(temp_df)
X2.shape, y2.shape
# Out:
# ((70085, 6, 5), (70085,))

# %%
X2_train, y2_train = X2[:60000], y2[:60000]
X2_val, y2_val = X2[60000:65000], y2[60000:65000]
X2_test, y2_test = X2[65000:], y2[65000:]
X2_train.shape, y2_train.shape, X2_val.shape, y2_val.shape, X2_test.shape, y2_test.shape
# Out:
# ((60000, 6, 5), (60000,), (5000, 6, 5), (5000,), (5085, 6, 5), (5085,))

# %%
temp_training_mean = np.mean(X2_train[:, :, 0])
temp_training_std = np.std(X2_train[:, :, 0])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - temp_training_mean) / temp_training_std
  return X

# %%
preprocess(X2_train)
preprocess(X2_val)
preprocess(X2_test)
# Out:
# array([[[ 1.04009706e+00, -9.65925826e-01,  2.58819045e-01,
#           5.22877889e-01, -8.52407598e-01],
#         [ 9.90732794e-01, -8.66025404e-01,  5.00000000e-01,
#           5.22266764e-01, -8.52782169e-01],
#         [ 8.49692028e-01, -7.07106781e-01,  7.07106781e-01,
#           5.21655371e-01, -8.53156301e-01],
#         [ 7.55664851e-01, -5.00000000e-01,  8.66025404e-01,
#           5.21043709e-01, -8.53529995e-01],
#         [ 6.66339032e-01, -2.58819045e-01,  9.65925826e-01,
#           5.20431780e-01, -8.53903251e-01],
#         [ 5.37051663e-01, -7.16474371e-12,  1.00000000e+00,
#           5.19819584e-01, -8.54276068e-01]],
#
#        [[ 9.90732794e-01, -8.66025404e-01,  5.00000000e-01,
#           5.22266764e-01, -8.52782169e-01],
#         [ 8.49692028e-01, -7.07106781e-01,  7.07106781e-01,
#           5.21655371e-01, -8.53156301e-01],
#         [ 7.55664851e-01, -5.00000000e-01,  8.66025404e-01,
#           5.21043709e-01, -8.53529995e-01],
# ...

# %%
model4 = Sequential()
model4.add(InputLayer((6, 5)))
model4.add(LSTM(64))
model4.add(Dense(8, 'relu'))
model4.add(Dense(1, 'linear'))

model4.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 64)             │        17,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 8)              │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,449 (72.07 KB)
#  Trainable params: 18,449 (72.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp4 = ModelCheckpoint('model4/model.keras', save_best_only=True)
model4.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model4.fit(X2_train, y2_train, validation_data=(X2_val, y2_val), epochs=10, callbacks=[cp4])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 93.2078 - root_mean_squared_error: 9.4676 - val_loss: 5.2745 - val_root_mean_squared_error: 2.2966
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 9.7427 - root_mean_squared_error: 3.1099 - val_loss: 2.5993 - val_root_mean_squared_error: 1.6122
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 3.4701 - root_mean_squared_error: 1.8597 - val_loss: 1.1833 - val_root_mean_squared_error: 1.0878
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.6326 - root_mean_squared_error: 1.2769 - val_loss: 0.8562 - val_root_mean_squared_error: 0.9253
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 1.1020 - root_mean_squared_error: 1.0496 - val_loss: 0.6796 - val_root_mean_squared_error: 0.8244
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.8521 - root_mean_squared_error: 0.9229 - val_loss: 0.5454 - val_root_mean_squared_error: 0.7385
# ...

# %%
plot_predictions1(model4, X2_test, y2_test)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# (      Predictions  Actuals
#  0       13.106786    13.46
#  1       12.774820    12.93
#  2       12.492699    12.43
#  3       12.198312    12.17
#  4       12.307687    11.55
#  ...           ...      ...
#  5080    -1.221655    -0.98
#  5081    -1.526969    -1.40
#  5082    -1.794459    -2.75
#  5083    -3.237531    -2.89
#  5084    -3.192216    -3.93
#
#  [5085 rows x 2 columns],
#  0.5219073510153289)

# %%
p_temp_df = pd.concat([df['p (mbar)'], temp_df], axis=1)
p_temp_df
# Out:
#                      p (mbar)  Temperature   Day sin   Day cos  Year sin  \
# Date Time
# 2009-01-01 01:00:00    996.50        -8.05  0.258819  0.965926  0.010049
# 2009-01-01 02:00:00    996.62        -8.88  0.500000  0.866025  0.010766
# 2009-01-01 03:00:00    996.84        -8.81  0.707107  0.707107  0.011483
# 2009-01-01 04:00:00    996.99        -9.05  0.866025  0.500000  0.012199
# 2009-01-01 05:00:00    997.46        -9.63  0.965926  0.258819  0.012916
# ...                       ...          ...       ...       ...       ...
# 2016-12-31 19:10:00   1002.18        -0.98 -0.953717  0.300706  0.006900
# 2016-12-31 20:10:00   1001.40        -1.40 -0.843391  0.537300  0.007617
# 2016-12-31 21:10:00   1001.19        -2.75 -0.675590  0.737277  0.008334
# 2016-12-31 22:10:00   1000.65        -2.89 -0.461749  0.887011  0.009050
# 2016-12-31 23:10:00   1000.11        -3.93 -0.216440  0.976296  0.009767
#
#                      Year cos
# Date Time
# 2009-01-01 01:00:00  0.999950
# ...

# %%
def df_to_X_y3(df, window_size=7):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [r for r in df_as_np[i:i+window_size]]
    X.append(row)
    label = [df_as_np[i+window_size][0], df_as_np[i+window_size][1]]
    y.append(label)
  return np.array(X), np.array(y)

# %%
X3, y3 = df_to_X_y3(p_temp_df)
X3.shape, y3.shape
# Out:
# ((70084, 7, 6), (70084, 2))

# %%
X3_train, y3_train = X3[:60000], y3[:60000]
X3_val, y3_val = X3[60000:65000], y3[60000:65000]
X3_test, y3_test = X3[65000:], y3[65000:]
X3_train.shape, y3_train.shape, X3_val.shape, y3_val.shape, X3_test.shape, y3_test.shape
# Out:
# ((60000, 7, 6), (60000, 2), (5000, 7, 6), (5000, 2), (5084, 7, 6), (5084, 2))

# %%
p_training_mean3 = np.mean(X3_train[:, :, 0])
p_training_std3 = np.std(X3_train[:, :, 0])

temp_training_mean3 = np.mean(X3_train[:, :, 1])
temp_training_std3 = np.std(X3_train[:, :, 1])

def preprocess3(X):
  X[:, :, 0] = (X[:, :, 0] - p_training_mean3) / p_training_std3
  X[:, :, 1] = (X[:, :, 1] - temp_training_mean3) / temp_training_std3
  return X

def preprocess_output(y):
  y[:, 0] = (y[:, 0] - p_training_mean3) / p_training_std3
  y[:, 1] = (y[:, 1] - temp_training_mean3) / temp_training_std3
  return y

# %%
preprocess3(X3_train)
preprocess3(X3_val)
preprocess3(X3_test)
# Out:
# array([[[-1.07355644e+00,  1.04009390e+00, -9.65925826e-01,
#           2.58819045e-01,  5.22877889e-01, -8.52407598e-01],
#         [-1.00807435e+00,  9.90728707e-01, -8.66025404e-01,
#           5.00000000e-01,  5.22266764e-01, -8.52782169e-01],
#         [-9.51080673e-01,  8.49685305e-01, -7.07106781e-01,
#           7.07106781e-01,  5.21655371e-01, -8.53156301e-01],
#         ...,
#         [-8.80748054e-01,  6.66328883e-01, -2.58819045e-01,
#           9.65925826e-01,  5.20431780e-01, -8.53903251e-01],
#         [-8.29817537e-01,  5.37039098e-01, -7.16474371e-12,
#           1.00000000e+00,  5.19819584e-01, -8.54276068e-01],
#         [-8.01927015e-01,  4.74744929e-01,  2.58819045e-01,
#           9.65925826e-01,  5.19207120e-01, -8.54648446e-01]],
#
#        [[-1.00807435e+00,  9.90728707e-01, -8.66025404e-01,
#           5.00000000e-01,  5.22266764e-01, -8.52782169e-01],
#         [-9.51080673e-01,  8.49685305e-01, -7.07106781e-01,
# ...

# %%
preprocess_output(y3_train)
preprocess_output(y3_val)
preprocess_output(y3_test)
# Out:
# array([[-0.7934386 ,  0.41245076],
#        [-0.76312281,  0.35368268],
#        [-0.72189335,  0.32312327],
#        ...,
#        [ 1.48145784, -1.43051636],
#        [ 1.41597574, -1.44697142],
#        [ 1.35049365, -1.56920903]])

# %%
model5 = Sequential()
model5.add(InputLayer((7, 6)))
model5.add(LSTM(64))
model5.add(Dense(8, 'relu'))
model5.add(Dense(2, 'linear'))

model5.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 64)             │        18,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 8)              │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 2)              │            18 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,714 (73.10 KB)
#  Trainable params: 18,714 (73.10 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp5 = ModelCheckpoint('model5/model.keras', save_best_only=True)
model5.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model5.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=10, callbacks=[cp5])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 0.5623 - root_mean_squared_error: 0.7384 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2110
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 0.0351 - root_mean_squared_error: 0.1869 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1275
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0148 - root_mean_squared_error: 0.1214 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0949
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0098 - root_mean_squared_error: 0.0990 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0833
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0756
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0061 - root_mean_squared_error: 0.0782 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# ...

# %%
def plot_predictions2(model, X, y, start=0, end=100):
  predictions = model.predict(X)
  p_preds, temp_preds = predictions[:, 0], predictions[:, 1]
  p_actuals, temp_actuals = y[:, 0], y[:, 1]
  df = pd.DataFrame(data={'Temperature Predictions': temp_preds,
                          'Temperature Actuals':temp_actuals,
                          'Pressure Predictions': p_preds,
                          'Pressure Actuals': p_actuals
                          })
  plt.plot(df['Temperature Predictions'][start:end])
  plt.plot(df['Temperature Actuals'][start:end])
  plt.plot(df['Pressure Predictions'][start:end])
  plt.plot(df['Pressure Actuals'][start:end])
  return df

# %%
plot_predictions2(model5, X3_test, y3_test)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#       Temperature Predictions  Temperature Actuals  Pressure Predictions  \
# 0                    0.405427             0.412451             -0.797427
# 1                    0.360645             0.353683             -0.780859
# 2                    0.322765             0.323123             -0.744725
# 3                    0.325431             0.250251             -0.690750
# 4                    0.274581             0.254952             -0.604581
# ...                       ...                  ...                   ...
# 5079                -1.249421            -1.222477              1.591076
# 5080                -1.272015            -1.271843              1.571169
# 5081                -1.290058            -1.430516              1.478646
# 5082                -1.454079            -1.446971              1.417633
# 5083                -1.456860            -1.569209              1.344629
#
#       Pressure Actuals
# 0            -0.793439
# ...

# %%
def postprocess_temp(arr):
  arr = (arr*temp_training_std3) + temp_training_mean3
  return arr

def postprocess_p(arr):
  arr = (arr*p_training_std3) + p_training_mean3
  return arr

# %%
def get_predictions_postprocessed(model, X, y):
  predictions = model.predict(X)
  p_preds, temp_preds = postprocess_p(predictions[:, 0]), postprocess_temp(predictions[:, 1])
  p_actuals, temp_actuals = postprocess_p(y[:, 0]), postprocess_temp(y[:, 1])
  df = pd.DataFrame(data={'Temperature Predictions': temp_preds,
                          'Temperature Actuals':temp_actuals,
                          'Pressure Predictions': p_preds,
                          'Pressure Actuals': p_actuals
                          })
  return df

# %%
post_processed_df = get_predictions_postprocessed(model5, X3_test, y3_test)
post_processed_df
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#       Temperature Predictions  Temperature Actuals  Pressure Predictions  \
# 0                   12.870240                12.93            982.397111
# 1                   12.489235                12.43            982.533737
# 2                   12.166949                12.17            982.831717
# 3                   12.189635                11.55            983.276823
# 4                   11.757005                11.59            983.987424
# ...                       ...                  ...                   ...
# 5079                -1.209237                -0.98           1002.093971
# 5080                -1.401464                -1.40           1001.929806
# 5081                -1.554975                -2.75           1001.166809
# 5082                -2.950471                -2.89           1000.663670
# 5083                -2.974130                -3.93           1000.061639
#
#       Pressure Actuals
# 0               982.43
# ...

# %%
start, end = 0, 100
plt.plot(post_processed_df['Temperature Predictions'][start:end])
plt.plot(post_processed_df['Temperature Actuals'][start:end])

# %%
plt.plot(post_processed_df['Pressure Predictions'][start:end])
plt.plot(post_processed_df['Pressure Actuals'][start:end])

# %%
model6 = Sequential()
model6.add(InputLayer((7, 6)))
model6.add(LSTM(32, return_sequences=True))
model6.add(LSTM(16))
model6.add(Dense(8, 'relu'))
model6.add(Dense(2, 'linear'))

model6.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 7, 32)          │         4,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 16)             │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 2)              │            18 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,282 (32.35 KB)
#  Trainable params: 8,282 (32.35 KB)
# ...

# %%
cp6 = ModelCheckpoint('model6/model.keras', save_best_only=True)
model6.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model6.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=10, callbacks=[cp6])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 0.4916 - root_mean_squared_error: 0.6877 - val_loss: 0.0523 - val_root_mean_squared_error: 0.2288
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - loss: 0.0470 - root_mean_squared_error: 0.2167 - val_loss: 0.0334 - val_root_mean_squared_error: 0.1826
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 0.0307 - root_mean_squared_error: 0.1750 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1431
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0171 - root_mean_squared_error: 0.1305 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0120 - root_mean_squared_error: 0.1088 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0087 - root_mean_squared_error: 0.0934 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# ...

# %%
model7 = Sequential()
model7.add(InputLayer((7, 6)))
model7.add(Conv1D(64, kernel_size=2, activation='relu'))
model7.add(Flatten())
model7.add(Dense(8, 'relu'))
model7.add(Dense(2, 'linear'))
model7.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_1 (Conv1D)               │ (None, 6, 64)          │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 384)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 8)              │         3,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 2)              │            18 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,930 (15.35 KB)
#  Trainable params: 3,930 (15.35 KB)
# ...

# %%
cp7 = ModelCheckpoint('model6/model.keras', save_best_only=True)
model7.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model7.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=10, callbacks=[cp7])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.1735 - root_mean_squared_error: 0.3901 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1329
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0095 - root_mean_squared_error: 0.0975 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0875
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0769
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0066 - root_mean_squared_error: 0.0810 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0725
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0064 - root_mean_squared_error: 0.0798 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 7/10
# ...
